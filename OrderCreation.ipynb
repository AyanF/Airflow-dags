# %% [markdown]
# <a href="https://colab.research.google.com/github/AyanF/Airflow-dags/blob/master/OrderCreation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import random
import pandas as pd  # type: ignore
import os

Address = {
    "WH_near": {
        "first_name": "Flora",
        "address1": "1234 W Camelback Rd",
        "phone": "08195868893",
        "city": "Phoenix",
        "zip": "85017",
        "province": "Arizona",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 33.5092,
        "longitude": -112.0930,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "AZ"
    },
    "Store_near": {
        "first_name": "Flora",
        "address1": "123 Main St",
        "phone": "08195868893",
        "city": "Ames",
        "zip": "50014",
        "province": "Iowa",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 42.0275,
        "longitude": -93.6485,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "IA"
    },
    "Both_same": {
        "first_name": "Flora",
        "address1": "123 Main St",
        "phone": "08195868893",
        "city": "Florence",
        "zip": "85132",
        "province": "Arizona",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 33.0314,
        "longitude": -111.3889,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "AZ"
    },
    "add1": {
        "first_name": "Flora",
        "address1": "218 N Bernard St",
        "phone": "+18666481322",
        "city": "Spokane",
        "zip": "99201",
        "province": "Washington",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 47.6587802,
        "longitude": -117.4260466,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "WA"
    },
    "add2": {
        "first_name": "Flora",
        "address1": "500 Wilcox St",
        "phone": "+18007357500",
        "city": "Joliet",
        "zip": "60435",
        "province": "Illinois",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 41.525031,
        "longitude": -88.081725,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "IL"
    },
    "add3": {
        "first_name": "Flora",
        "address1": "48 Essex St",
        "phone": "+13479478075",
        "city": "Brooklyn",
        "zip": "11208",
        "province": "New York",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 40.6761673,
        "longitude": -73.8716245,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "NY"
    },
    "add4": {
        "first_name": "Flora",
        "address1": "44 Moosehead Trail",
        "phone": "+12073684733",
        "city": "Newport",
        "zip": "04953",
        "province": "Maine",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 44.8353669,
        "longitude": -69.2742115,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "ME"
    },
    "add5": {
        "first_name": "Flora",
        "address1": "1500 South Capitol St SE",
        "phone": "+12026756287",
        "city": "Washington",
        "zip": "20003",
        "province": "District of Columbia",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 38.8689373,
        "longitude": -77.0090505,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "DC"
    },
    "add6": {
        "first_name": "Flora",
        "address1": "20555 AL-183",
        "phone": "+13346838966",
        "city": "Marion",
        "zip": "36756",
        "province": "Alabama",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 32.646007,
        "longitude": -87.318202,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "AL"
    },
    "add7": {
        "first_name": "Flora",
        "address1": "3400 Sky Hbr Blvd",
        "phone": "+16022733300",
        "city": "Phoenix",
        "zip": "85034",
        "province": "Arizona",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 33.4341667,
        "longitude": -112.011667,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "AZ"
    },
    "add8": {
        "first_name": "Flora",
        "address1": "14801 Farm to Market Rd 182",
        "phone": "+12543261027",
        "city": "Valley Mills",
        "zip": "76689",
        "province": "Texas",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 31.656784,
        "longitude": -97.483268,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "TX"
    },
    "add9": {
        "first_name": "Flora",
        "address1": "19250 N Tamiami Trl",
        "phone": "+12397311441",
        "city": "North Fort Myers",
        "zip": "33903",
        "province": "Florida",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 26.707147,
        "longitude": -81.895479,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "FL"
    },
    "add10": {
        "first_name": "Flora",
        "address1": "1002 Industrial Blvd",
        "phone": "+16194255127",
        "city": "Chula Vista",
        "zip": "91911",
        "province": "California",
        "country": "United States",
        "last_name": "Next",
        "address2": "",
        "company": "",
        "latitude": 32.592472,
        "longitude": -117.041622,
        "name": "Flora Next",
        "country_code": "US",
        "province_code": "CA"
    }
}

def get_shipping_choice():
    choice = int(input("Enter 1 for 'Next Day', 2 for 'Two Day', or 3 for 'Standard shipping': "))
    shipping_methods = {
        1: 'Next Day',
        2: 'Two Day',
        3: 'Standard shipping'
    }
    return shipping_methods.get(choice, "Invalid choice")

def read_json_file(filename):
    with open(filename, 'r') as file:
        return json.load(file)

def write_json_file(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file, indent=4)

def create_new_order(order_json, new_address, shipping_method, line_items, tag):
    if len(order_json["order"]["line_items"]) < line_items:
        raise ValueError("Original order must have at least", line_items, "line items")

    selected_line_items = random.sample(order_json["order"]["line_items"], line_items)
    order_json["order"]["line_items"] = selected_line_items

    order_json["order"]["id"] = random.randint(1000000000000, 9999999999999)
    order_json["order"]['admin_graphql_api_id'] = f"gid://shopify/Order/{order_json['order']['id']}"
    order_json["order"]["number"] = random.randint(100000, 999999)
    order_json["order"]["order_number"] = order_json["order"]["number"]
    order_json["order"]["name"] = f"RBRK#{order_json['order']['number']}"

    orderId = str(order_json["order"]["id"])

    if tag:
        order_json["order"]["tags"] = tag

    order_json["order"]["shipping_address"] = new_address
    order_json["order"]["customer"]["default_address"] = new_address
    order_json["order"]["billing_address"] = new_address
    order_json["order"]["customer"]["first_name"] = "Standard"
    order_json["order"]["customer"]["last_name"] = "Shipping"

    for shipping_line in order_json['order']['shipping_lines']:
        shipping_line['code'] = shipping_method
        shipping_line['title'] = shipping_method

    return order_json , orderId

def get_tags():
    choice = int(input("Enter 1 for 'LoyaltyPlusOrder', 2 for 'LoyaltyOrder', 3 for None: "))
    tags = {
        1: 'LoyaltyPlusOrder',
        2: 'LoyaltyOrder',
        3: None
    }
    return tags.get(choice, "Invalid choice")

new_address = Address["add3"]
shipping_choice = get_shipping_choice()
tag = get_tags()
line_items = int(input("Enter the number of line items required for the order"))
file_path = "order.json"

with open(file_path, 'r') as file:
    original_order_json = json.load(file)

orderIds = []

for i in range(4):
    new_order, orderId = create_new_order(original_order_json.copy(), new_address, shipping_choice, line_items, tag)
    new_order_json = [new_order["order"]]
    output_filename = f"new_order_{i+1}.json"
    with open(output_filename, 'w') as outfile:
        json.dump(new_order_json, outfile, indent=2)

    orderIds.append(orderId)
    print(f"Generated {output_filename}")


# Print the generated order IDs in the required format
formatted_order_ids = ", ".join(f'"{order_id}"' for order_id in orderIds)
print(f"{{{formatted_order_ids}}}")
# Out:
# Enter 1 for 'Next Day', 2 for 'Two Day', or 3 for 'Standard shipping': 1
# Enter 1 for 'LoyaltyPlusOrder', 2 for 'LoyaltyOrder', 3 for None: 3
# Enter the number of line items required for the order3
# Generated new_order_1.json
# Generated new_order_2.json
# Generated new_order_3.json
# Generated new_order_4.json
# {"2794813513009", "2074244837133", "8626804585968", "3094221568621"}

# %%
from google.colab import drive
drive.mount('/content/drive')
